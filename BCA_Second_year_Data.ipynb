# %%
#Import needed class and function
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#Read the dataset
data=pd.read_csv('BCA_Second_Year_Data.csv')
data
# Out:
#             Timestamp           Email Address Mail ID (Instituitional ID)  \
# 0   5/8/2022 17:49:11  ca205113435@bhc.edu.in      ca205113435@bhc.edu.in
# 1   5/8/2022 17:49:22  ca205113467@bhc.edu.in      Ca205113467@bhc.edu.in
# 2   5/8/2022 17:49:25  ca205113464@bhc.edu.in     ca205113464@bhc.edu.in
# 3   5/8/2022 17:49:39  ca205113466@bhc.edu.in      Ca205113466@bhc.edu.in
# 4   5/8/2022 17:50:33  ca205113425@bhc.edu.in     ca205113425@bhc.edu.in
# 5   5/8/2022 17:50:43  ca205113408@bhc.edu.in      ca205113408@bhc.edu.in
# 6   5/8/2022 17:51:23  ca205113458@bhc.edu.in      ca205113458@bhc.edu.in
# 7   5/8/2022 17:52:19  ca205113417@bhc.edu.in      ca205113417@bhc.edu.in
# 8   5/8/2022 17:56:09  ca205113461@bhc.edu.in      ca205113461@bhc.edu.in
# 9   5/8/2022 17:57:26  ca205113429@bhc.edu.in      ca205113429@bhc.edu.in
# 10  5/8/2022 18:00:12  ca205113468@bhc.edu.in     Ca205113468@bhc.edu.in
# 11  5/8/2022 18:00:27  ca205113448@bhc.edu.in      ca205113448@bhc.edu.in
# ...

# %%
data.pop('Timestamp')
data.pop('Email Address')
data.pop('Mail ID (Instituitional ID)')
data.pop('Name')
data.pop('Class and Sec')
# Out:
# 0     BCA D
# 1     BCA D
# 2     BCA D
# 3     BCA D
# 4     BCA D
# 5     BCA D
# 6     BCA D
# 7     BCA D
# 8     BCA D
# 9     BCA D
# 10    BCA D
# 11    BCA D
# 12    BCA D
# 13    BCA D
# 14    BCA D
# 15    BCA D
# 16    BCA D
# 17    BCA D
# 18    BCA D
# 19    BCA D
# 20    BCA D
# 21    BCA D
# 22    BCA D
# 23    BCA D
# 24    BCA D
# 25    BCA D
# 26    BCA D
# 27    BCA D
# 28    BCA D
# 29    BCA D
# 30    BCA D
# 31    BCA D
# 32    BCA D
# 33    BCA D
# 34    BCA D
# 35    BCA D
# 36    BCA D
# 37    BCA D
# 38    BCA D
# 39    BCA D
# Name: Class and Sec, dtype: object

# %%
data
# Out:
#    CONTACT NUMBER (WHAT'S APP NUM) ARE YOU INTERESTED IN PLACEMENT ?  \
# 0                       7397666650                               YES
# 1                       8300076152                               YES
# 2                       9600268935                               YES
# 3                       8300153690                               YES
# 4                       9360536771                               YES
# 5                       9345612260                               YES
# 6                       8124970701                               YES
# 7                       8122594001                               YES
# 8                       7010394259                               YES
# 9                       6380173993                               YES
# 10                    96298 22238                                YES
# 11                      6380296778                               YES
# 12                      9600661103                               YES
# ...

# %%
#Inference:
1. Half of the students are willing to study Higher studies in Bishop Heber College.
2. Half of the students are interested to get placed in a company with 5 to 10 lakhs per annum package.
3. Less than 25% of students are interested to get placed in a company with > 10 lakhs per annum package.

Hence Placement Officer can give training to this class for the company hiring from 5 lakhs to 15 lakhs
Higher Education Coordinator can give session about how to get admission in Bishop Heber College for Masters Courses
and how to get admission in other top colleges for Masters Course
